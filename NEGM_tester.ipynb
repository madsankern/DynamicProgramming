# %%
# magics: ensures that any changes to the modules loaded below will be re-loaded automatically
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import tools 
from model_1d import model_1d

# Setup model
model = model_1d()
model.setup()
model.create_grids()

# Solve using NEGM
model.solve_negm_dc()
sol = model.sol_negm
par = model.par

# %%
plt.scatter(sol.m[0],sol.v[0])

# %%
plt.scatter(sol.m[0],sol.c[0])

# %%
plt.scatter(sol.m[0],sol.h[0])

# %%
plt.scatter(sol.m[1],sol.v[1])

# %%
plt.scatter(sol.m[1],sol.h[1])

# %%
plt.scatter(sol.m[1],sol.c[1])
