# %%
# magics: ensures that any changes to the modules loaded below will be re-loaded automatically
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import tools 
from model import model_class as model

# Setup model
model = model()
model.setup()
model.create_grids()

# %%
# Solve using simple EGM
model.solve_egm()
sol = model.sol_egm
par = model.par

# %%
# Plot simple EGM results (there are functions for each income process)
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Simple EGM')
ax1.plot(sol.m[0], sol.v[0])
ax1.set_title("Value function")
#ax1.set_ylim(-5,10)
ax2.plot(sol.m[0], sol.c[0])
ax2.set_title("Policy function (c)")
fig.tight_layout(w_pad=1.5)

# %%
# Solve using NEGM
model.solve_negm_dc()
sol = model.sol_negm
par = model.par

# %%
# Plot NEGM results
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2,3)
fig.suptitle('NEGM')
ax1.plot(sol.m[0], sol.v[0])
ax1.set_title("Value function")
#ax1.set_ylim(-5,10)
ax2.plot(sol.m[0], sol.c[0])
ax2.set_title("Policy function (c)")
#ax2.set_xlim(0,10)
#ax2.set_ylim(0,6)
ax3.plot(sol.m[0], sol.h[0])
ax3.set_title("Policy function (h)")
ax4.plot(sol.m[1], sol.v[1])
#ax4.set_ylim(-5,10)
ax5.plot(sol.m[1], sol.c[1])
#ax5.set_xlim(0,10)
#ax5.set_ylim(0,6)
ax6.plot(sol.m[1], sol.h[1])
fig.tight_layout(w_pad=1.5)

# %%
# Plot delta/distance parameter for each state (NEGM)
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Delta, convergence')

ax1.plot(range(sol.it), sol.delta_save[0, :sol.it])
ax1.set_title("n=0")

ax2.plot(range(sol.it), sol.delta_save[1, :sol.it])
ax2.set_title("n=1")

fig.tight_layout(w_pad=1.5)

# %%
# Solve using NVFI
model.solve_vfi_dc()
sol = model.sol_nvfi
par = model.par

# %%
# Plot NVFI results
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2,3)
fig.suptitle('NVFI')
ax1.plot(sol.m[0], sol.v[0])
ax1.set_title("Value function")
#ax1.set_ylim(-5,10)
ax2.plot(sol.m[0], sol.c[0])
ax2.set_title("Policy function (c)")
#ax2.set_ylim(0,6)
ax3.plot(sol.m[0], sol.h[0])
ax3.set_title("Policy function (h)")
ax4.plot(sol.m[1], sol.v[1])
#ax4.set_ylim(-5,10)
ax5.plot(sol.m[1], sol.c[1])
#ax5.set_ylim(0,6)
ax6.plot(sol.m[1], sol.h[1])
fig.tight_layout(w_pad=1.5)

# %%
# Plot delta/distance parameter for each state (NVFI)
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Delta, convergence')

ax1.plot(range(sol.it), sol.delta_save[0, :sol.it])
ax1.set_title("n=0")

ax2.plot(range(sol.it), sol.delta_save[1, :sol.it])
ax2.set_title("n=1")

fig.tight_layout(w_pad=1.5)
